# %%
import numpy as np
import pandas as pd

import math

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link7.csv')
df2 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link2.csv')
df3 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link3.csv')
df4 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link4.csv')
df5 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link5.csv')
df6 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link6.csv')
df7 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link1.csv')
df8 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link8.csv')

df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df2,df1,df7,df6,df8,df4,df5,df3])
df
# Out:
#                Timestamp  Tx_Packet  Rx_Packet  Dropped  BW_Utilization
# 0    2020-11-06 04:30:24         33         34        0    4.584070e+04
# 1    2020-11-06 04:31:21         35         33        0    4.626071e+04
# 2    2020-11-06 04:35:26         40          5        0    4.150660e+05
# 3    2020-11-06 04:35:27        143          1        0    4.224566e+06
# 4    2020-11-06 04:35:28        142          0        0    4.165482e+06
# ..                   ...        ...        ...      ...             ...
# 120  2020-11-06 04:39:41        327        274        0    8.398220e+05
# 121  2020-11-06 04:39:41        217          0        0    3.031080e+05
# 122  2020-11-06 04:39:41        304          3        0    4.266560e+05
# 123  2020-11-06 04:39:42        913          1        0    1.280100e+06
# 124  2020-11-06 04:39:42        613          1        0    8.562560e+05
#
# [3406 rows x 5 columns]

# %%
# Because we will predict BW Util

df = df.reset_index()['BW_Utilization']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(14,5))
plt.plot(df)

# %%
# Scaling data

scaler = MinMaxScaler(feature_range=(0,1))
df = scaler.fit_transform(np.array(df).reshape(-1,1))

df
# Out:
# array([[0.00298178],
#        [0.00303186],
#        [0.04701144],
#        ...,
#        [0.04839353],
#        [0.15016566],
#        [0.09962279]])

# %%
df.shape
# Out:
# (3406, 1)

# %%
plt.figure(figsize =(14,5))
plt.plot(df)

# %%
training_size=int(len(df)*0.75)
test_size=len(df)-training_size


train_data, test_data = df[0:training_size,:] , df[training_size:len(df),:1]

# %%
import numpy
# convert an array of values into a dataset matrix

def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4

time_step = 200
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
X_train.shape
# Out:
# (2353, 200)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from tensorflow.keras.regularizers import l2

# %%
model=Sequential()

model.add(LSTM(100,return_sequences=True,input_shape=(200,1), activation="relu", kernel_regularizer=l2(0.01)\
               , recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
#model.add(LSTM(80, activation="relu",return_sequences=True, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01)\
#               , bias_regularizer=l2(0.01)))
model.add(LSTM(50, activation="relu", kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01)\
               , bias_regularizer=l2(0.01)))

model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlyStop=EarlyStopping(monitor="val_loss",verbose=1,mode='min',patience=10)

# %%
#Train the model

model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1,callbacks=[earlyStop])
# Out:
# Train on 2353 samples, validate on 651 samples
# Epoch 1/100
# 2353/2353 [==============================] - 36s 15ms/sample - loss: 3.3932 - val_loss: 2.5330
# Epoch 2/100
# 2353/2353 [==============================] - 27s 11ms/sample - loss: 2.0911 - val_loss: 1.7388
# Epoch 3/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 1.5409 - val_loss: 1.3780
# Epoch 4/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 1.2743 - val_loss: 1.1863
# Epoch 5/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 1.1200 - val_loss: 1.0614
# Epoch 6/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 1.0119 - val_loss: 0.9668
# Epoch 7/100
# 2353/2353 [==============================] - 27s 11ms/sample - loss: 0.9237 - val_loss: 0.8841
# Epoch 8/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.8460 - val_loss: 0.8106
# Epoch 9/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.7754 - val_loss: 0.7426
# Epoch 10/100
# 2353/2353 [==============================] - 27s 11ms/sample - loss: 0.7101 - val_loss: 0.6800
# Epoch 11/100
# 2353/2353 [==============================] - 27s 11ms/sample - loss: 0.6496 - val_loss: 0.6217
# Epoch 12/100
# 2353/2353 [==============================] - 27s 12ms/sample - loss: 0.5934 - val_loss: 0.5673
# Epoch 13/100
# 2353/2353 [==============================] - 27s 11ms/sample - loss: 0.5411 - val_loss: 0.5172
# Epoch 14/100
# 2353/2353 [==============================] - 27s 12ms/sample - loss: 0.4925 - val_loss: 0.4706
# Epoch 15/100
# 2353/2353 [==============================] - 31s 13ms/sample - loss: 0.4476 - val_loss: 0.4273
# Epoch 16/100
# 2353/2353 [==============================] - 39s 17ms/sample - loss: 0.4063 - val_loss: 0.3875
# Epoch 17/100
# 2353/2353 [==============================] - 34s 15ms/sample - loss: 0.3678 - val_loss: 0.3510
# Epoch 18/100
# 2353/2353 [==============================] - 29s 12ms/sample - loss: 0.3324 - val_loss: 0.3170
# Epoch 19/100
# 2353/2353 [==============================] - 28s 12ms/sample - loss: 0.3000 - val_loss: 0.2858
# Epoch 20/100
# 2353/2353 [==============================] - 21s 9ms/sample - loss: 0.2702 - val_loss: 0.2573
# Epoch 21/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.2429 - val_loss: 0.2313
# Epoch 22/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.2181 - val_loss: 0.2076
# Epoch 23/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.1955 - val_loss: 0.1865
# Epoch 24/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.1750 - val_loss: 0.1667
# Epoch 25/100
# 2353/2353 [==============================] - 23s 10ms/sample - loss: 0.1564 - val_loss: 0.1489
# Epoch 26/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.1396 - val_loss: 0.1332
# Epoch 27/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.1247 - val_loss: 0.1188
# Epoch 28/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.1111 - val_loss: 0.1066
# Epoch 29/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.0989 - val_loss: 0.0948
# Epoch 30/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0881 - val_loss: 0.0846
# Epoch 31/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0784 - val_loss: 0.0753
# Epoch 32/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.0699 - val_loss: 0.0685
# Epoch 33/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0624 - val_loss: 0.0613
# Epoch 34/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0558 - val_loss: 0.0545
# Epoch 35/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0498 - val_loss: 0.0485
# Epoch 36/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0446 - val_loss: 0.0439
# Epoch 37/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0402 - val_loss: 0.0394
# Epoch 38/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0364 - val_loss: 0.0365
# Epoch 39/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0329 - val_loss: 0.0327
# Epoch 40/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0300 - val_loss: 0.0300
# Epoch 41/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0274 - val_loss: 0.0276
# Epoch 42/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0252 - val_loss: 0.0258
# Epoch 43/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0234 - val_loss: 0.0240
# Epoch 44/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0219 - val_loss: 0.0224
# Epoch 45/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0205 - val_loss: 0.0211
# Epoch 46/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0193 - val_loss: 0.0199
# Epoch 47/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0184 - val_loss: 0.0191
# Epoch 48/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0175 - val_loss: 0.0190
# Epoch 49/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0166 - val_loss: 0.0181
# Epoch 50/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0161 - val_loss: 0.0169
# Epoch 51/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0155 - val_loss: 0.0165
# Epoch 52/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0149 - val_loss: 0.0162
# Epoch 53/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0145 - val_loss: 0.0156
# Epoch 54/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0142 - val_loss: 0.0153
# Epoch 55/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0138 - val_loss: 0.0149
# Epoch 56/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0135 - val_loss: 0.0149
# Epoch 57/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0132 - val_loss: 0.0142
# Epoch 58/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.0129 - val_loss: 0.0141
# Epoch 59/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.0127 - val_loss: 0.0144
# Epoch 60/100
# 2353/2353 [==============================] - 27s 11ms/sample - loss: 0.0125 - val_loss: 0.0135
# Epoch 61/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.0123 - val_loss: 0.0137
# Epoch 62/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0122 - val_loss: 0.0132
# Epoch 63/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0120 - val_loss: 0.0131
# Epoch 64/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0117 - val_loss: 0.0129
# Epoch 65/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0116 - val_loss: 0.0127
# Epoch 66/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0115 - val_loss: 0.0128
# Epoch 67/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0114 - val_loss: 0.0125
# Epoch 68/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0113 - val_loss: 0.0124
# Epoch 69/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0112 - val_loss: 0.0127
# Epoch 70/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.0112 - val_loss: 0.0123
# Epoch 71/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0111 - val_loss: 0.0122
# Epoch 72/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0110 - val_loss: 0.0121
# Epoch 73/100
# 2353/2353 [==============================] - 18s 7ms/sample - loss: 0.0110 - val_loss: 0.0121
# Epoch 74/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0108 - val_loss: 0.0120
# Epoch 75/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0108 - val_loss: 0.0121
# Epoch 76/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0108 - val_loss: 0.0119
# Epoch 77/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0108 - val_loss: 0.0118
# Epoch 78/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0108 - val_loss: 0.0118
# Epoch 79/100
# 2353/2353 [==============================] - 18s 7ms/sample - loss: 0.0106 - val_loss: 0.0117
# Epoch 80/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0105 - val_loss: 0.0117
# Epoch 81/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0105 - val_loss: 0.0119
# Epoch 82/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0106 - val_loss: 0.0116
# Epoch 83/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0106 - val_loss: 0.0116
# Epoch 84/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0108 - val_loss: 0.0121
# Epoch 85/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0104 - val_loss: 0.0115
# Epoch 86/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0104 - val_loss: 0.0118
# Epoch 87/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0103 - val_loss: 0.0115
# Epoch 88/100
# 2353/2353 [==============================] - 18s 7ms/sample - loss: 0.0103 - val_loss: 0.0115
# Epoch 89/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0103 - val_loss: 0.0115
# Epoch 90/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0102 - val_loss: 0.0113
# Epoch 91/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0101 - val_loss: 0.0113
# Epoch 92/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0101 - val_loss: 0.0113
# Epoch 93/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0101 - val_loss: 0.0115
# Epoch 94/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0100 - val_loss: 0.0112
# Epoch 95/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0101 - val_loss: 0.0112
# Epoch 96/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0102 - val_loss: 0.0111
# Epoch 97/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0100 - val_loss: 0.0111
# Epoch 98/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0099 - val_loss: 0.0111
# Epoch 99/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0101 - val_loss: 0.0111
# Epoch 100/100
# 2353/2353 [==============================] - 16s 7ms/sample - loss: 0.0100 - val_loss: 0.0112

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 0.05574682817549102

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 0.06581172453504157

# %%
### Plotting 
# shift train predictions for plotting
# look back = timestep

look_back=200

trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict

# plot baseline and predictions
plt.figure(figsize =(14,5))
#plt.plot(scaler.inverse_transform(df))
plt.plot(df)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

#ORANGE = Train predicted Data
#GREEN = Test predicted Data

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 3632359.2126209037

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 4962804.1544951

# %%
### Plotting 
# shift train predictions for plotting
# look back = timestep

look_back=200

trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict

# plot baseline and predictions
plt.figure(figsize =(14,5))
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

#ORANGE = Train predicted Data
#GREEN = Test predicted Data
