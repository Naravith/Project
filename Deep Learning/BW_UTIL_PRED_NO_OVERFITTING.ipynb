# %%
import numpy as np
import pandas as pd

import math

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link7.csv')
df2 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link2.csv')
df3 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link3.csv')
df4 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link4.csv')
df5 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link5.csv')
df6 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link6.csv')
df7 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link1.csv')
df8 = pd.read_csv('C:\\Users\\Luxuss\\Desktop\\SharedFolder\\Project\\RYU\\link8.csv')

df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df2,df1,df7,df6,df8,df4,df5,df3])
df.reset_index(inplace=True)
df
# Out:
#       index            Timestamp  Tx_Packet  Rx_Packet  Dropped  \
# 0         0  2020-11-06 04:30:24         33         34        0
# 1         1  2020-11-06 04:31:21         35         33        0
# 2         2  2020-11-06 04:35:26         40          5        0
# 3         3  2020-11-06 04:35:27        143          1        0
# 4         4  2020-11-06 04:35:28        142          0        0
# ...     ...                  ...        ...        ...      ...
# 3401    120  2020-11-06 04:39:41        327        274        0
# 3402    121  2020-11-06 04:39:41        217          0        0
# 3403    122  2020-11-06 04:39:41        304          3        0
# 3404    123  2020-11-06 04:39:42        913          1        0
# 3405    124  2020-11-06 04:39:42        613          1        0
#
#       BW_Utilization
# 0       4.584070e+04
# 1       4.626071e+04
# 2       4.150660e+05
# 3       4.224566e+06
# 4       4.165482e+06
# ...              ...
# 3401    8.398220e+05
# 3402    3.031080e+05
# 3403    4.266560e+05
# 3404    1.280100e+06
# 3405    8.562560e+05
#
# [3406 rows x 6 columns]

# %%
# Because we will predict BW Util

df = df.reset_index()['BW_Utilization']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize =(14,5))
plt.plot(df)

# %%
# Scaling data

scaler = MinMaxScaler(feature_range=(0,1))
df = scaler.fit_transform(np.array(df).reshape(-1,1))

df
# Out:
# array([[0.00298178],
#        [0.00303186],
#        [0.04701144],
#        ...,
#        [0.04839353],
#        [0.15016566],
#        [0.09962279]])

# %%
df.shape
# Out:
# (3406, 1)

# %%
plt.figure(figsize =(14,5))
plt.plot(df)

# %%
training_size=int(len(df)*0.75)
test_size=len(df)-training_size


train_data, test_data = df[0:training_size,:] , df[training_size:len(df),:1]

# %%
import numpy
# convert an array of values into a dataset matrix

def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4

time_step = 200
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
X_train.shape
# Out:
# (2353, 200)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from tensorflow.keras.regularizers import l2

# %%
model=Sequential()

model.add(LSTM(100,return_sequences=True,input_shape=(200,1), activation="relu", kernel_regularizer=l2(0.01)\
               , recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
#model.add(LSTM(80, activation="relu",return_sequences=True, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01)\
#               , bias_regularizer=l2(0.01)))
model.add(LSTM(50, activation="relu", kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01)\
               , bias_regularizer=l2(0.01)))

model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

earlyStop=EarlyStopping(monitor="val_loss",verbose=1,mode='min',patience=10)

# %%
#Train the model

model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1,callbacks=[earlyStop])
# Out:
# Train on 2353 samples, validate on 651 samples
# Epoch 1/100
# 2353/2353 [==============================] - 27s 12ms/sample - loss: 3.3896 - val_loss: 2.5238
# Epoch 2/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 2.0801 - val_loss: 1.7294
# Epoch 3/100
# 2353/2353 [==============================] - 21s 9ms/sample - loss: 1.5327 - val_loss: 1.3710
# Epoch 4/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 1.2693 - val_loss: 1.1820
# Epoch 5/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 1.1175 - val_loss: 1.0598
# Epoch 6/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 1.0108 - val_loss: 0.9656
# Epoch 7/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.9237 - val_loss: 0.8854
# Epoch 8/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.8466 - val_loss: 0.8114
# Epoch 9/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.7762 - val_loss: 0.7436
# Epoch 10/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.7110 - val_loss: 0.6809
# Epoch 11/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.6507 - val_loss: 0.6232
# Epoch 12/100
# 2353/2353 [==============================] - 18s 7ms/sample - loss: 0.5944 - val_loss: 0.5685
# Epoch 13/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.5421 - val_loss: 0.5192
# Epoch 14/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.4935 - val_loss: 0.4718
# Epoch 15/100
# 2353/2353 [==============================] - 20s 9ms/sample - loss: 0.4486 - val_loss: 0.4291
# Epoch 16/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.4072 - val_loss: 0.3896
# Epoch 17/100
# 2353/2353 [==============================] - 29s 12ms/sample - loss: 0.3688 - val_loss: 0.3520
# Epoch 18/100
# 2353/2353 [==============================] - 23s 10ms/sample - loss: 0.3336 - val_loss: 0.3181
# Epoch 19/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.3011 - val_loss: 0.2871
# Epoch 20/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.2716 - val_loss: 0.2588
# Epoch 21/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.2443 - val_loss: 0.2329
# Epoch 22/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.2194 - val_loss: 0.2094
# Epoch 23/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.1969 - val_loss: 0.1875
# Epoch 24/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.1764 - val_loss: 0.1687
# Epoch 25/100
# 2353/2353 [==============================] - 21s 9ms/sample - loss: 0.1577 - val_loss: 0.1508
# Epoch 26/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.1412 - val_loss: 0.1357
# Epoch 27/100
# 2353/2353 [==============================] - 20s 9ms/sample - loss: 0.1258 - val_loss: 0.1204
# Epoch 28/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.1122 - val_loss: 0.1074
# Epoch 29/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.1001 - val_loss: 0.0965
# Epoch 30/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0892 - val_loss: 0.0859
# Epoch 31/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0795 - val_loss: 0.0765
# Epoch 32/100
# 2353/2353 [==============================] - 20s 9ms/sample - loss: 0.0709 - val_loss: 0.0683
# Epoch 33/100
# 2353/2353 [==============================] - 25s 11ms/sample - loss: 0.0634 - val_loss: 0.0616
# Epoch 34/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.0568 - val_loss: 0.0549
# Epoch 35/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.0510 - val_loss: 0.0496
# Epoch 36/100
# 2353/2353 [==============================] - 25s 11ms/sample - loss: 0.0456 - val_loss: 0.0453
# Epoch 37/100
# 2353/2353 [==============================] - 25s 11ms/sample - loss: 0.0410 - val_loss: 0.0405
# Epoch 38/100
# 2353/2353 [==============================] - 21s 9ms/sample - loss: 0.0371 - val_loss: 0.0367
# Epoch 39/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.0337 - val_loss: 0.0339
# Epoch 40/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0308 - val_loss: 0.0311
# Epoch 41/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0282 - val_loss: 0.0284
# Epoch 42/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0261 - val_loss: 0.0270
# Epoch 43/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0243 - val_loss: 0.0251
# Epoch 44/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0227 - val_loss: 0.0232
# Epoch 45/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0213 - val_loss: 0.0218
# Epoch 46/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0199 - val_loss: 0.0208
# Epoch 47/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0190 - val_loss: 0.0198
# Epoch 48/100
# 2353/2353 [==============================] - 21s 9ms/sample - loss: 0.0183 - val_loss: 0.0191
# Epoch 49/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0174 - val_loss: 0.0187
# Epoch 50/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0167 - val_loss: 0.0178
# Epoch 51/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0162 - val_loss: 0.0174
# Epoch 52/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.0158 - val_loss: 0.0169
# Epoch 53/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.0154 - val_loss: 0.0164
# Epoch 54/100
# 2353/2353 [==============================] - 32s 14ms/sample - loss: 0.0149 - val_loss: 0.0161
# Epoch 55/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.0146 - val_loss: 0.0161
# Epoch 56/100
# 2353/2353 [==============================] - 21s 9ms/sample - loss: 0.0144 - val_loss: 0.0158
# Epoch 57/100
# 2353/2353 [==============================] - 25s 11ms/sample - loss: 0.0141 - val_loss: 0.0152
# Epoch 58/100
# 2353/2353 [==============================] - 28s 12ms/sample - loss: 0.0139 - val_loss: 0.0154
# Epoch 59/100
# 2353/2353 [==============================] - 25s 11ms/sample - loss: 0.0137 - val_loss: 0.0147
# Epoch 60/100
# 2353/2353 [==============================] - 21s 9ms/sample - loss: 0.0134 - val_loss: 0.0146
# Epoch 61/100
# 2353/2353 [==============================] - 24s 10ms/sample - loss: 0.0132 - val_loss: 0.0144
# Epoch 62/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0131 - val_loss: 0.0145
# Epoch 63/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0130 - val_loss: 0.0140
# Epoch 64/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0127 - val_loss: 0.0140
# Epoch 65/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0126 - val_loss: 0.0143
# Epoch 66/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0125 - val_loss: 0.0137
# Epoch 67/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0124 - val_loss: 0.0134
# Epoch 68/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0122 - val_loss: 0.0134
# Epoch 69/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.0122 - val_loss: 0.0137
# Epoch 70/100
# 2353/2353 [==============================] - 31s 13ms/sample - loss: 0.0122 - val_loss: 0.0131
# Epoch 71/100
# 2353/2353 [==============================] - 22s 9ms/sample - loss: 0.0119 - val_loss: 0.0129
# Epoch 72/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.0117 - val_loss: 0.0130
# Epoch 73/100
# 2353/2353 [==============================] - 30s 13ms/sample - loss: 0.0117 - val_loss: 0.0128
# Epoch 74/100
# 2353/2353 [==============================] - 26s 11ms/sample - loss: 0.0116 - val_loss: 0.0128
# Epoch 75/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0115 - val_loss: 0.0128
# Epoch 76/100
# 2353/2353 [==============================] - 21s 9ms/sample - loss: 0.0115 - val_loss: 0.0126
# Epoch 77/100
# 2353/2353 [==============================] - 23s 10ms/sample - loss: 0.0113 - val_loss: 0.0125
# Epoch 78/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0113 - val_loss: 0.0125
# Epoch 79/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0113 - val_loss: 0.0123
# Epoch 80/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0111 - val_loss: 0.0122
# Epoch 81/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0110 - val_loss: 0.0123
# Epoch 82/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0110 - val_loss: 0.0121
# Epoch 83/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0112 - val_loss: 0.0121
# Epoch 84/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.0108 - val_loss: 0.0120
# Epoch 85/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.0108 - val_loss: 0.0119
# Epoch 86/100
# 2353/2353 [==============================] - 20s 9ms/sample - loss: 0.0108 - val_loss: 0.0119
# Epoch 87/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0107 - val_loss: 0.0118
# Epoch 88/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0107 - val_loss: 0.0121
# Epoch 89/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0107 - val_loss: 0.0118
# Epoch 90/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0106 - val_loss: 0.0118
# Epoch 91/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0106 - val_loss: 0.0117
# Epoch 92/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0105 - val_loss: 0.0119
# Epoch 93/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0105 - val_loss: 0.0118
# Epoch 94/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0104 - val_loss: 0.0118
# Epoch 95/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0105 - val_loss: 0.0118
# Epoch 96/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0104 - val_loss: 0.0115
# Epoch 97/100
# 2353/2353 [==============================] - 18s 8ms/sample - loss: 0.0105 - val_loss: 0.0122
# Epoch 98/100
# 2353/2353 [==============================] - 17s 7ms/sample - loss: 0.0105 - val_loss: 0.0115
# Epoch 99/100
# 2353/2353 [==============================] - 20s 8ms/sample - loss: 0.0103 - val_loss: 0.0115
# Epoch 100/100
# 2353/2353 [==============================] - 19s 8ms/sample - loss: 0.0102 - val_loss: 0.0115

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 0.05620466715709088

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 0.06540808528795164

# %%
mean_absolute_error(ytest,test_predict)
# Out:
# 0.03182483581372333

# %%
### Plotting 
# shift train predictions for plotting
# look back = timestep

look_back=200

trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict

# plot baseline and predictions
plt.figure(figsize =(14,5))
#plt.plot(scaler.inverse_transform(df))
plt.plot(df)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

#ORANGE = Train predicted Data
#GREEN = Test predicted Data

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 3839313.107031896

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 5156717.438021059

# %%
mean_absolute_error(ytest,test_predict)
# Out:
# 4732775.427793937

# %%
### Plotting 
# shift train predictions for plotting
# look back = timestep

look_back=200

trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict

# plot baseline and predictions
plt.figure(figsize =(14,5))
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

#ORANGE = Train predicted Data
#GREEN = Test predicted Data
