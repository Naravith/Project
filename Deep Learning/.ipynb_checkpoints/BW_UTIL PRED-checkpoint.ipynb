# %% [markdown]
# # LSTM

# %%
import numpy as np
import pandas as pd

import math

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:\\Users\\Naravith\\Desktop\\ปี4\\Project - github\\Project\\RYU\\link4.csv')
df
# Out:
#                Timestamp  Tx_Packet  Rx_Packet  BW_Utilization
# 0    2020-10-27 11:44:04         37         45        0.004477
# 1    2020-10-27 11:45:54         20          0        0.001142
# 2    2020-10-27 11:45:55        773        244        0.181570
# 3    2020-10-27 11:45:56       1319       2243        0.601182
# 4    2020-10-27 11:45:57       1307       2314        0.612060
# ..                   ...        ...        ...             ...
# 274  2020-10-27 11:51:49        265          1        0.164200
# 275  2020-10-27 11:51:50        261          0        0.153910
# 276  2020-10-27 11:51:51        254          1        0.140826
# 277  2020-10-27 11:51:52        234          0        0.148933
# 278  2020-10-27 11:51:53        101          2        0.047742
#
# [279 rows x 4 columns]

# %%
# Because we will predict BW Util

df1 = df.reset_index()['BW_Utilization']

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
# Scaling data

scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

df1
# Out:
# array([[0.00445695],
#        [0.        ],
#        [0.24115216],
#        [0.80198687],
#        [0.81652623],
#        [0.82492642],
#        [0.83265879],
#        [0.79893885],
#        [0.84536329],
#        [0.82974079],
#        [0.82441962],
#        [0.83048079],
#        [0.83726749],
#        [0.84499772],
#        [0.82135824],
#        [0.8431811 ],
#        [0.81406638],
#        [0.8562063 ],
#        [0.774825  ],
#        [0.79559837],
#        [0.74804664],
#        [0.86527195],
#        [0.84732511],
#        [0.82651574],
#        [0.83170648],
#        [0.8381839 ],
#        [0.83505838],
#        [0.81122454],
#        [0.82268305],
#        [0.82736139],
#        [0.80978094],
#        [0.84317886],
#        [0.81939468],
#        [0.81868731],
#        [0.82671326],
#        [0.82235654],
#        [0.8208542 ],
#        [0.81949747],
#        [0.82397635],
#        [0.83431063],
#        [0.80452962],
#        [0.81222509],
#        [0.83546045],
#        [0.84444035],
#        [0.83084758],
#        [0.81093117],
#        [0.81371172],
#        [0.78749502],
#        [0.77240899],
#        [0.808579  ],
#        [0.76205208],
#        [0.7611219 ],
#        [0.53042964],
#        [0.54075097],
#        [0.54218978],
#        [0.53659798],
#        [0.5255803 ],
#        [0.54278458],
#        [0.52893882],
#        [0.55179955],
#        [0.53757354],
#        [0.52925585],
#        [0.50988468],
#        [0.4840413 ],
#        [0.54694256],
#        [0.52835126],
#        [0.5345191 ],
#        [0.54931563],
#        [0.53010252],
#        [0.54142102],
#        [0.51844231],
#        [0.52382078],
#        [0.53271125],
#        [0.5205523 ],
#        [0.51732766],
#        [0.52373299],
#        [0.52374257],
#        [0.51257683],
#        [0.52445505],
#        [0.51326941],
#        [0.52779613],
#        [0.52721153],
#        [0.49402856],
#        [0.52473628],
#        [0.48935278],
#        [0.66813311],
#        [0.91038575],
#        [0.96193791],
#        [0.96425388],
#        [0.99454485],
#        [0.98424463],
#        [1.        ],
#        [0.86767439],
#        [0.99860819],
#        [0.91620841],
#        [0.93614531],
#        [0.89943333],
#        [0.8223337 ],
#        [0.92032723],
#        [0.88762903],
#        [0.91758369],
#        [0.8455503 ],
#        [0.99056552],
#        [0.83203259],
#        [0.78919856],
#        [0.80863478],
#        [0.81806855],
#        [0.79568586],
#        [0.80852934],
#        [0.8962922 ],
#        [0.84266778],
#        [0.7609355 ],
#        [0.79045402],
#        [0.77335029],
#        [0.68103115],
#        [0.66923491],
#        [0.64710716],
#        [0.62803181],
#        [0.74967757],
#        [0.64009072],
#        [0.550747  ],
#        [0.55416926],
#        [0.50743329],
#        [0.51554929],
#        [0.55193813],
#        [0.53478442],
#        [0.52680232],
#        [0.5229268 ],
#        [0.52456946],
#        [0.53802629],
#        [0.29621887],
#        [0.31862776],
#        [0.27610871],
#        [0.28008253],
#        [0.27352955],
#        [0.23032078],
#        [0.20850566],
#        [0.18540969],
#        [0.17107346],
#        [0.19036345],
#        [0.21437054],
#        [0.18931325],
#        [0.202243  ],
#        [0.19884858],
#        [0.21871594],
#        [0.01166316],
#        [0.14685366],
#        [0.68701105],
#        [0.82165916],
#        [0.82401816],
#        [0.82358478],
#        [0.82270569],
#        [0.82609521],
#        [0.81778099],
#        [0.81880478],
#        [0.8239424 ],
#        [0.82189216],
#        [0.82197455],
#        [0.82225977],
#        [0.82997511],
#        [0.82101154],
#        [0.82465232],
#        [0.82576605],
#        [0.81850407],
#        [0.82179957],
#        [0.825179  ],
#        [0.82569559],
#        [0.81485288],
#        [0.8237356 ],
#        [0.82791244],
#        [0.82826088],
#        [0.82158737],
#        [0.82260535],
#        [0.82303832],
#        [0.82516911],
#        [0.82633913],
#        [0.8236945 ],
#        [0.82226303],
#        [0.82164131],
#        [0.82205572],
#        [0.82823059],
#        [0.8227579 ],
#        [0.82230667],
#        [0.82929058],
#        [0.81847235],
#        [0.81575543],
#        [0.81984682],
#        [0.81794353],
#        [0.8143052 ],
#        [0.82362037],
#        [0.82582162],
#        [0.78794145],
#        [0.75649067],
#        [0.75369177],
#        [0.75997289],
#        [0.75794784],
#        [0.62075739],
#        [0.53008325],
#        [0.52978029],
#        [0.53681926],
#        [0.53843408],
#        [0.54427458],
#        [0.53400445],
#        [0.52657431],
#        [0.53520108],
#        [0.53106839],
#        [0.538761  ],
#        [0.41722934],
#        [0.42455312],
#        [0.42916977],
#        [0.43372115],
#        [0.42665301],
#        [0.41390121],
#        [0.42677926],
#        [0.44709376],
#        [0.42473137],
#        [0.42001336],
#        [0.41397605],
#        [0.54875469],
#        [0.8728789 ],
#        [0.8695941 ],
#        [0.87765819],
#        [0.86308252],
#        [0.82051382],
#        [0.87502131],
#        [0.87651295],
#        [0.86732228],
#        [0.74858831],
#        [0.79283465],
#        [0.85359655],
#        [0.8093859 ],
#        [0.8213512 ],
#        [0.831785  ],
#        [0.83257691],
#        [0.84554061],
#        [0.84292189],
#        [0.83629703],
#        [0.91191471],
#        [0.89322205],
#        [0.84262842],
#        [0.8665731 ],
#        [0.77729861],
#        [0.80481147],
#        [0.83417103],
#        [0.84412699],
#        [0.82328183],
#        [0.79971842],
#        [0.75982064],
#        [0.80700314],
#        [0.77274733],
#        [0.81806824],
#        [0.83292239],
#        [0.81517205],
#        [0.84250361],
#        [0.853522  ],
#        [0.85509664],
#        [0.79855054],
#        [0.7680693 ],
#        [0.73066269],
#        [0.82178866],
#        [0.72306624],
#        [0.69879484],
#        [0.65709289],
#        [0.53942014],
#        [0.41664026],
#        [0.42626104],
#        [0.39109748],
#        [0.29802304],
#        [0.23348974],
#        [0.19990041],
#        [0.22517215],
#        [0.18766601],
#        [0.19847761],
#        [0.20119912],
#        [0.21793566],
#        [0.20418321],
#        [0.18669545],
#        [0.1975305 ],
#        [0.06228331]])

# %% [markdown]
# ### Train - Test Split

# %%
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size


train_data, test_data = df1[0:training_size,:] , df1[training_size:len(df1),:1]

# %%
import numpy
# convert an array of values into a dataset matrix

def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4

time_step = 50
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
X_train.shape
# Out:
# (130, 50)

# %% [markdown]
# ### Reshape input to be [samples, timesteps, features]

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
X_train
# Out:
# array([[[0.00445695],
#         [0.        ],
#         [0.24115216],
#         ...,
#         [0.78749502],
#         [0.77240899],
#         [0.808579  ]],
#
#        [[0.        ],
#         [0.24115216],
#         [0.80198687],
#         ...,
#         [0.77240899],
#         [0.808579  ],
#         [0.76205208]],
#
#        [[0.24115216],
#         [0.80198687],
#         [0.81652623],
#         ...,
#         [0.808579  ],
#         [0.76205208],
#         [0.7611219 ]],
#
#        ...,
#
#        [[0.5229268 ],
#         [0.52456946],
#         [0.53802629],
#         ...,
#         [0.82516911],
#         [0.82633913],
#         [0.8236945 ]],
#
#        [[0.52456946],
#         [0.53802629],
#         [0.29621887],
#         ...,
#         [0.82633913],
#         [0.8236945 ],
#         [0.82226303]],
#
#        [[0.53802629],
#         [0.29621887],
#         [0.31862776],
#         ...,
#         [0.8236945 ],
#         [0.82226303],
#         [0.82164131]]])

# %% [markdown]
# ### Creating and Training LSTM Model

# %%
model=Sequential()
model.add(LSTM(120,return_sequences=True,input_shape=(50,1)))
model.add(LSTM(100,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
#Train the model

model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Train on 130 samples, validate on 47 samples
# Epoch 1/100
# 130/130 [==============================] - 6s 43ms/sample - loss: 0.2526 - val_loss: 0.1711
# Epoch 2/100
# 130/130 [==============================] - 0s 614us/sample - loss: 0.1023 - val_loss: 0.0545
# Epoch 3/100
# 130/130 [==============================] - 0s 529us/sample - loss: 0.0502 - val_loss: 0.0509
# Epoch 4/100
# 130/130 [==============================] - 0s 534us/sample - loss: 0.0480 - val_loss: 0.0808
# Epoch 5/100
# 130/130 [==============================] - 0s 522us/sample - loss: 0.0577 - val_loss: 0.0581
# Epoch 6/100
# 130/130 [==============================] - 0s 509us/sample - loss: 0.0415 - val_loss: 0.0449
# Epoch 7/100
# 130/130 [==============================] - 0s 520us/sample - loss: 0.0535 - val_loss: 0.0572
# Epoch 8/100
# 130/130 [==============================] - 0s 499us/sample - loss: 0.0614 - val_loss: 0.0429
# Epoch 9/100
# 130/130 [==============================] - 0s 506us/sample - loss: 0.0428 - val_loss: 0.0446
# Epoch 10/100
# 130/130 [==============================] - 0s 496us/sample - loss: 0.0401 - val_loss: 0.0602
# Epoch 11/100
# 130/130 [==============================] - 0s 522us/sample - loss: 0.0425 - val_loss: 0.0468
# Epoch 12/100
# 130/130 [==============================] - 0s 521us/sample - loss: 0.0362 - val_loss: 0.0408
# Epoch 13/100
# 130/130 [==============================] - 0s 506us/sample - loss: 0.0330 - val_loss: 0.0354
# Epoch 14/100
# 130/130 [==============================] - 0s 506us/sample - loss: 0.0315 - val_loss: 0.0332
# Epoch 15/100
# 130/130 [==============================] - 0s 507us/sample - loss: 0.0314 - val_loss: 0.0325
# Epoch 16/100
# 130/130 [==============================] - 0s 522us/sample - loss: 0.0321 - val_loss: 0.0306
# Epoch 17/100
# 130/130 [==============================] - 0s 529us/sample - loss: 0.0289 - val_loss: 0.0314
# Epoch 18/100
# 130/130 [==============================] - 0s 513us/sample - loss: 0.0280 - val_loss: 0.0309
# Epoch 19/100
# 130/130 [==============================] - 0s 510us/sample - loss: 0.0251 - val_loss: 0.0240
# Epoch 20/100
# 130/130 [==============================] - 0s 506us/sample - loss: 0.
# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 0.20279679940172488

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 0.19316881487470794

# %%
### Plotting 
# shift train predictions for plotting
# look back = timestep

look_back=50
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

#ORANGE = Train predicted Data
#GREEN = Test predicted Data

# %% [markdown]
# #  Regression and Decision Tree Regressor

# %%
df_reg = pd.read_csv('C:\\Users\\Naravith\\Desktop\\ปี4\\Project - github\\Project\\RYU\\link4.csv')

df_reg = df_reg[['BW_Utilization']]
df_reg
# Out:
#      BW_Utilization
# 0          0.004477
# 1          0.001142
# 2          0.181570
# 3          0.601182
# 4          0.612060
# ..              ...
# 274        0.164200
# 275        0.153910
# 276        0.140826
# 277        0.148933
# 278        0.047742
#
# [279 rows x 1 columns]

# %%
future_days = 25

# %%
df_reg['Prediction'] = df_reg[['BW_Utilization']].shift(-future_days)
df_reg.tail(30)
# Out:
#      BW_Utilization  Prediction
# 249        0.579305    0.164200
# 250        0.613214    0.153910
# 251        0.624327    0.140826
# 252        0.611047    0.148933
# 253        0.631496    0.047742
# 254        0.639740         NaN
# 255        0.640918         NaN
# 256        0.598611         NaN
# 257        0.575805         NaN
# 258        0.547818         NaN
# 259        0.615997         NaN
# 260        0.542134         NaN
# 261        0.523974         NaN
# 262        0.492773         NaN
# 263        0.404732         NaN
# 264        0.312869         NaN
# 265        0.320067         NaN
# 266        0.293758         NaN
# 267        0.224120         NaN
# 268        0.175837         NaN
# 269        0.150706         NaN
# 270        0.169614         NaN
# 271        0.141552         NaN
# 272        0.149641         NaN
# 273        0.151678         NaN
# 274        0.164200         NaN
# 275        0.153910         NaN
# 276        0.140826         NaN
# 277        0.148933         NaN
# 278        0.047742         NaN

# %%
# Create the feature dataset (X) and convert to numpy array and remove the last 'x' rows days
X = np.array(df_reg.drop(['Prediction'],1))[:-future_days]
X
# Out:
# array([[0.004477  ],
#        [0.00114235],
#        [0.18157021],
#        [0.60118164],
#        [0.61205986],
#        [0.6183448 ],
#        [0.6241301 ],
#        [0.59890114],
#        [0.63363548],
#        [0.62194687],
#        [0.61796562],
#        [0.62250053],
#        [0.62757828],
#        [0.63336197],
#        [0.61567513],
#        [0.63200279],
#        [0.61021942],
#        [0.64174812],
#        [0.58085937],
#        [0.59640182],
#        [0.56082405],
#        [0.64853096],
#        [0.6351033 ],
#        [0.61953392],
#        [0.62341759],
#        [0.62826393],
#        [0.62592545],
#        [0.60809319],
#        [0.61666634],
#        [0.62016663],
#        [0.60701309],
#        [0.63200111],
#        [0.61420601],
#        [0.61367676],
#        [0.6196817 ],
#        [0.61642204],
#        [0.615298  ],
#        [0.61428291],
#        [0.61763397],
#        [0.62536598],
#        [0.60308411],
#        [0.60884178],
#        [0.62622627],
#        [0.63294495],
#        [0.62277496],
#        [0.60787369],
#        [0.60995407],
#        [0.59033897],
#        [0.57905174],
#        [0.60611382],
#        [0.5713028 ],
#        [0.57060684],
#        [0.39800499],
#        [0.40572731],
#        [0.40680382],
#        [0.40262009],
#        [0.39437675],
#        [0.40724884],
#        [0.39688957],
#        [0.31539253],
#        [0.31087547],
#        [0.41171562],
#        [0.65422241],
#        [0.65176476],
#        [0.65779823],
#        [0.64689285],
#        [0.61504333],
#        [0.65582535],
#        [0.65694138],
#        [0.650065  ],
#        [0.56122932],
#        [0.59433403],
#        [0.63979553],
#        [0.60671753],
#        [0.61566986],
#        [0.62347633],
#        [0.62406883],
#        [0.63376816],
#        [0.63180885],
#        [0.62685219],
#        [0.68342865],
#        [0.66944298],
#        [0.63158928],
#        [0.64950447],
#        [0.58271011],
#        [0.60329498],
#        [0.62526154],
#        [0.63271049],
#        [0.61711433],
#        [0.59948441],
#        [0.56963326],
#        [0.60493477],
#        [0.57930489],
#        [0.61321358],
#        [0.62432732],
#        [0.61104668],
#        [0.6314959 ]])

# %%
X.shape
# Out:
# (254, 1)

# %%
# Create target dataset (y), convert to nparray and get all of target value except the last 'x' rows or days
y = np.array(df_reg['Prediction'])[:-future_days]
y
# Out:
# array([0.62826393, 0.62592545, 0.60809319, 0.61666634, 0.62016663,
#        0.60701309, 0.63200111, 0.61420601, 0.61367676, 0.6196817 ,
#        0.61642204, 0.615298  , 0.61428291, 0.61763397, 0.62536598,
#        0.60308411, 0.60884178, 0.62622627, 0.63294495, 0.62277496,
#        0.60787369, 0.60995407, 0.59033897, 0.57905174, 0.60611382,
#        0.5713028 , 0.57060684, 0.39800499, 0.40572731, 0.40680382,
#        0.40262009, 0.39437675, 0.40724884, 0.39688957, 0.41399376,
#        0.40334999, 0.39712677, 0.38263344, 0.36329765, 0.4103598 ,
#        0.39644997, 0.40106468, 0.41213531, 0.39776024, 0.40622864,
#        0.38903618, 0.3930603 , 0.39971207, 0.39061485, 0.38820221,
#        0.39299461, 0.39300179, 0.38464767, 0.39353485, 0.38516586,
#        0.39603462, 0.39559723, 0.37077003, 0.39374527, 0.36727165,
#        0.50103348, 0.6822847 , 0.72085556, 0.72258835, 0.74525177,
#        0.73754524, 0.74933327, 0.65032845, 0.74829193, 0.68664116,
#        0.70155777, 0.67409019, 0.61640495, 0.68972282, 0.66525833,
#        0.68767014, 0.63377541, 0.74227448, 0.62366158, 0.59161354,
#        0.60615555, 0.61321381, 0.59646729, 0.60607666, 0.67174004,
#        0.63161873, 0.57046738, 0.59255287, 0.57975601, 0.51068367,
#        0.50185783, 0.48530205, 0.47103004, 0.5620443 , 0.48005241,
#        0.41320625, 0.41576675, 0.38079933, 0.38687164, 0.41409744,
#        0.4012632 , 0.39529106, 0.39239143, 0.39362045, 0.40368874,
#        0.22277061, 0.23953674, 0.20772438, 0.21069756, 0.20579468,
#        0.17346626, 0.15714439, 0.1398642 , 0.12913795, 0.14357056,
#        0.16153244, 0.14278481, 0.15245872, 0.14991905, 0.16478363,
#        0.00986862, 0.11101692, 0.51515778, 0.61590027, 0.61766525,
#        0.617341  , 0.61668327, 0.61921928, 0.61299866, 0.61376465,
#        0.61760857, 0.6160746 , 0.61613625, 0.61634964, 0.62212219,
#        0.61541573, 0.61813972, 0.61897301, 0.61353966, 0.61600533,
#        0.61853378, 0.61892029, 0.61080788, 0.61745384, 0.62057892,
#        0.62083961, 0.61584656, 0.6166082 , 0.61693214, 0.61852638,
#        0.61940178, 0.6174231 , 0.61635208, 0.61588692, 0.61619698,
#        0.62081696, 0.61672234, 0.61638474, 0.62161003, 0.61351593,
#        0.61148315, 0.6145443 , 0.61312027, 0.6103981 , 0.61736763,
#        0.61901459, 0.59067299, 0.5671418 , 0.56504768, 0.56974716,
#        0.56823204, 0.46558739, 0.39774582, 0.39751915, 0.40278564,
#        0.40399384, 0.40836365, 0.40067963, 0.39512047, 0.40157494,
#        0.39848289, 0.40423843, 0.31330956, 0.31878914, 0.32224327,
#        0.32564857, 0.32036026, 0.31081947, 0.32045471, 0.33565384,
#        0.3189225 , 0.31539253, 0.31087547, 0.41171562, 0.65422241,
#        0.65176476, 0.65779823, 0.64689285, 0.61504333, 0.65582535,
#        0.65694138, 0.650065  , 0.56122932, 0.59433403, 0.63979553,
#        0.60671753, 0.61566986, 0.62347633, 0.62406883, 0.63376816,
#        0.63180885, 0.62685219, 0.68342865, 0.66944298, 0.63158928,
#        0.64950447, 0.58271011, 0.60329498, 0.62526154, 0.63271049,
#        0.61711433, 0.59948441, 0.56963326, 0.60493477, 0.57930489,
#        0.61321358, 0.62432732, 0.61104668, 0.6314959 , 0.63973976,
#        0.64091789, 0.59861061, 0.57580482, 0.54781754, 0.61599716,
#        0.54213394, 0.5239743 , 0.49277328, 0.4047316 , 0.3128688 ,
#        0.32006699, 0.29375793, 0.22412048, 0.17583725, 0.15070602,
#        0.16961411, 0.14155235, 0.14964149, 0.1516777 , 0.16419983,
#        0.15391037, 0.14082619, 0.14893288, 0.04774216])

# %%
# Split the data into 75% train and 25% test and create the model
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = 0.25)

#Create a model
tree = DecisionTreeRegressor().fit(x_train, y_train)
lr = LinearRegression().fit(x_train, y_train)

# %%
y_train.shape
# Out:
# (190,)

# %%
# Get the last 'x' rows of feature dataset (Last 25 days)
x_future = df_reg.drop(['Prediction'],1)[:-future_days]
x_future = x_future.tail(future_days)

#convert to np array
x_future = np.array(x_future)
x_future

# X_Future is the input for model prediction
# Out:
# array([[0.63979553],
#        [0.60671753],
#        [0.61566986],
#        [0.62347633],
#        [0.62406883],
#        [0.63376816],
#        [0.63180885],
#        [0.62685219],
#        [0.68342865],
#        [0.66944298],
#        [0.63158928],
#        [0.64950447],
#        [0.58271011],
#        [0.60329498],
#        [0.62526154],
#        [0.63271049],
#        [0.61711433],
#        [0.59948441],
#        [0.56963326],
#        [0.60493477],
#        [0.57930489],
#        [0.61321358],
#        [0.62432732],
#        [0.61104668],
#        [0.6314959 ]])

# %%
tree_prediction = tree.predict(x_future)
lr_prediction = lr.predict(x_future)

print(tree_prediction)
# Out:
# [0.63973976 0.64091789 0.62536598 0.57580482 0.54781754 0.61599716
#  0.54213394 0.5239743  0.57046738 0.4047316  0.3128688  0.62432732
#  0.29375793 0.22412048 0.17583725 0.15070602 0.16961411 0.14155235
#  0.14964149 0.1516777  0.16419983 0.15391037 0.63200111 0.14893288
#  0.3128688 ]

# %%
tree_prediction.shape
# Out:
# (25,)

# %%
math.sqrt(mean_squared_error(y_test[-25:],tree_prediction))
# Out:
# 0.2642422323682812

# %%
math.sqrt(mean_squared_error(y_test[-25:],lr_prediction))
# Out:
# 0.16338823098774352
